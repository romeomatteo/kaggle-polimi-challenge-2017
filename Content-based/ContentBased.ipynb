# %%
from pyspark import SparkContext
import numpy as np
sc = SparkContext.getOrCreate()

# %%
icm = sc.textFile("../icm.csv")
icm = icm.map(lambda l: l.split(','))\
            .filter(lambda line: line[0] != 'itemId')\
            .map(lambda l: (int(l[0][0]), int(l[0][1])))
icm.take(5)
# Out:
# [(2, 1), (2, 3), (6, 2), (1, 2), (2, 4)]

# %%
itemFeature = icm.map(lambda x: (x[0],[x[1]])).reduce(lambda x,y: x+y)
itemFeature.take(5)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-4-d6c6a5586d56> in <module>()
# ----> 1 itemFeature = icm.map(lambda x: (x[0],[x[1]])).reduce(lambda x,y: x+y)
#       2 itemFeature.take(5)
#
# /usr/lib/spark/python/pyspark/rdd.py in reduce(self, f)
#     833             yield reduce(f, iterator, initial)
#     834
# --> 835         vals = self.mapPartitions(func).collect()
#     836         if vals:
#     837             return reduce(f, vals)
#
# /usr/lib/spark/python/pyspark/rdd.py in collect(self)
#     807         """
#     808         with SCCallSiteSync(self.context) as css:
# --> 809             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     810         return list(_load_from_socket(port, self._jrdd_deserializer))
#     811
#
# /usr/lib/spark/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in __call__(self, *args)
# ...
